# %% [markdown]
# # Nigeria extract oil provinces

# %%
import geopandas as gpd

#import geoplot
# %matplotlib inline

# %%
oil_states= ['Akwa Ibom','Delta','Rivers','Bayelsa','Ondo','Edo State','Imo','Abia']

# %%
map = gpd.read_file('/Users/knuttungland/src/Nigeria/data/Nigeriabound97.shp')

# %%
map.plot()

# %%
oil_states_map = map[map['name'].isin(oil_states)]

# %%
oil_states_map.plot()

# %%
oil_states_map.to_file('data_out.shp')

# %%
import geopandas as gpd

# %matplotlib inline

# %%
map = gpd.read_file('/Users/knuttungland/src/Nigeria/data/nigeria-lgas/new_lga_nigeria_2003.dbf')

# %%
map.plot()

# %%
map
# Out:
#            STATE             LGA       AREA  PERIMETER LONGITUDE LATITUDE  \
# 0         Sokoto            Gada   1193.977    170.095      None     None
# 1         Sokoto          Illela   1298.423    174.726      None     None
# 2         Sokoto         Tangaza   2460.715    209.702      None     None
# 3          Borno          Abadam   2430.515    288.957      None     None
# 4           Lake       Lake chad   5225.912    497.039      None     None
# 5         Sokoto     Sabon Birni   2241.750    201.102      None     None
# 6         Sokoto       Gwadabawa   1009.712    172.871      None     None
# 7         Sokoto         Goronyo   1651.610    255.140      None     None
# 8         Sokoto           Wurno    642.076    140.928      None     None
# 9           Yobe        Yusufari   4292.148    376.191      None     None
# 10          Yobe        Yunusari   3880.036    347.123      None     None
# 11       Katsina           Kaita    972.081    137.735      None     None
# ...
